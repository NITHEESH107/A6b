# %% [markdown]
# # PART A: ARCH_GARCH Model

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\nithe\anaconda3\lib\site-packages (0.2.41)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\nithe\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nithe\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\nithe\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\nithe\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nithe\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nithe\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nithe\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nithe\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nithe\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nithe\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
# !pip install arch
# Out:
# Requirement already satisfied: arch in c:\users\nithe\anaconda3\lib\site-packages (7.0.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\nithe\anaconda3\lib\site-packages (from arch) (1.24.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\nithe\anaconda3\lib\site-packages (from arch) (1.11.1)
# Requirement already satisfied: pandas>=1.4 in c:\users\nithe\anaconda3\lib\site-packages (from arch) (2.0.3)
# Requirement already satisfied: statsmodels>=0.12 in c:\users\nithe\anaconda3\lib\site-packages (from arch) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nithe\anaconda3\lib\site-packages (from pandas>=1.4->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nithe\anaconda3\lib\site-packages (from pandas>=1.4->arch) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nithe\anaconda3\lib\site-packages (from pandas>=1.4->arch) (2023.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\nithe\anaconda3\lib\site-packages (from statsmodels>=0.12->arch) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\nithe\anaconda3\lib\site-packages (from statsmodels>=0.12->arch) (23.1)
# Requirement already satisfied: six in c:\users\nithe\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.12->arch) (1.16.0)

# %%
import yfinance as yf
from arch import arch_model
import matplotlib.pyplot as plt

# %%
# Get the data for AMAZON
ticker = "AMZN"

# Download the data
data = yf.download(ticker, start="2021-04-01", end="2024-03-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Create 'Returns' column
data['Returns'] = 100 * data['Adj Close'].pct_change().dropna()

# Fit an ARCH model
arch_model_fit = arch_model(data['Returns'].dropna(), vol='ARCH', p=1).fit(disp='off')
print(arch_model_fit.summary())

# Plot the conditional volatility
arch_model_fit.conditional_volatility.plot(title='Conditional Volatility (ARCH)')
plt.show()
# Out:
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                Returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -1680.83
# Distribution:                  Normal   AIC:                           3367.67
# Method:            Maximum Likelihood   BIC:                           3381.54
#                                         No. Observations:                  752
# Date:                Thu, Jul 25 2024   Df Residuals:                      751
# Time:                        23:07:08   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.0369  7.986e-02      0.461      0.644 [ -0.120,  0.193]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega          3.8822      0.412      9.431  4.071e-21 [  3.075,  4.689]
# alpha[1]       0.3336      0.115      2.900  3.732e-03 [  0.108,  0.559]
# ========================================================================
#
# Covariance estimator: robust

# %%
# Drop NaN values from 'Returns'
returns = data['Returns'].dropna()

# Fit a GARCH model
garch_model_fit = arch_model(returns, vol='Garch', p=1, q=1).fit(disp='off')
print(garch_model_fit.summary())

# Plot the conditional volatility
garch_model_fit.conditional_volatility.plot(title='Conditional Volatility (GARCH)')
plt.show()
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                Returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -1658.75
# Distribution:                  Normal   AIC:                           3325.51
# Method:            Maximum Likelihood   BIC:                           3344.00
#                                         No. Observations:                  752
# Date:                Thu, Jul 25 2024   Df Residuals:                      751
# Time:                        23:07:08   Df Model:                            1
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# mu             0.1113  7.240e-02      1.537      0.124 [-3.064e-02,  0.253]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.3633      0.356      1.021      0.307    [ -0.334,  1.061]
# alpha[1]       0.1862      0.128      1.450      0.147 [-6.554e-02,  0.438]
# beta[1]        0.7639      0.159      4.792  1.654e-06    [  0.451,  1.076]
# ===========================================================================
#
# Covariance estimator: robust

# %%
am = arch_model(returns, vol="Garch", p=1, o=0, q=1, dist="Normal")
res = am.fit(update_freq=10)
# Out:
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 1658.7534267877502
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1658.753425723704
#             Iterations: 12
#             Function evaluations: 71
#             Gradient evaluations: 12

# %%
forecasts = res.forecast()

# %%
type(forecasts)
# Out:
# arch.univariate.base.ARCHModelForecast

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-22  177.750000  179.259995  176.750000  178.869995  178.869995
# 2024-03-25  178.009995  180.990005  177.240005  179.710007  179.710007
# 2024-03-26  180.149994  180.449997  177.949997  178.300003  178.300003
# 2024-03-27  179.880005  180.000000  177.309998  179.830002  179.830002
# 2024-03-28  180.169998  181.699997  179.259995  180.380005  180.380005
#
#               Volume   Returns
# Date
# 2024-03-22  27964100  0.404155
# 2024-03-25  29815500  0.469621
# 2024-03-26  29659000 -0.784599
# 2024-03-27  33272600  0.858104
# 2024-03-28  38051600  0.305846

# %%
print(forecasts.mean.iloc[-3:])
print(forecasts.residual_variance.iloc[-3:])
print(forecasts.variance.iloc[-3:])
# Out:
#                  h.1
# Date
# 2024-03-28  0.111253
#                  h.1
# Date
# 2024-03-28  2.000285
#                  h.1
# Date
# 2024-03-28  2.000285

# %%
forecasts = res.forecast(horizon=90)
print(forecasts.residual_variance.iloc[-3:])
# Out:
#                 h.01      h.02      h.03      h.04      h.05      h.06  \
# Date
# 2024-03-28  2.000285  2.263874  2.514326  2.752297  2.978409  3.193253
#
#                h.07      h.08      h.09      h.10  ...      h.81      h.82  \
# Date                                               ...
# 2024-03-28  3.39739  3.591354  3.775652  3.950766  ...  7.200975  7.205389
#
#                 h.83      h.84      h.85      h.86      h.87     h.88  \
# Date
# 2024-03-28  7.209583  7.213569  7.217355  7.220953  7.224372  7.22762
#
#                 h.89      h.90
# Date
# 2024-03-28  7.230707  7.233639
#
# [1 rows x 90 columns]

# %%
forecasts.residual_variance
# Out:
#                 h.01      h.02      h.03      h.04      h.05      h.06  \
# Date
# 2024-03-28  2.000285  2.263874  2.514326  2.752297  2.978409  3.193253
#
#                h.07      h.08      h.09      h.10  ...      h.81      h.82  \
# Date                                               ...
# 2024-03-28  3.39739  3.591354  3.775652  3.950766  ...  7.200975  7.205389
#
#                 h.83      h.84      h.85      h.86      h.87     h.88  \
# Date
# 2024-03-28  7.209583  7.213569  7.217355  7.220953  7.224372  7.22762
#
#                 h.89      h.90
# Date
# 2024-03-28  7.230707  7.233639
#
# [1 rows x 90 columns]

# %%
fig = res.plot(annualize="D")
